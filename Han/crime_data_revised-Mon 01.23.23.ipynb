# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("CrimeDate.csv")
df
# Out:
#               date                      primary_type  crime_count  \
# 0       2001-01-01               MOTOR VEHICLE THEFT           59
# 1       2001-01-01                 WEAPONS VIOLATION           32
# 2       2001-01-01                DECEPTIVE PRACTICE           78
# 3       2001-01-01                 CRIMINAL TRESPASS           29
# 4       2001-01-01                          GAMBLING            2
# ...            ...                               ...          ...
# 141850  2022-06-14                         NARCOTICS           15
# 141851  2022-06-14                 CRIMINAL TRESPASS           11
# 141852  2022-06-14                     OTHER OFFENSE           33
# 141853  2022-06-14                 WEAPONS VIOLATION           29
# 141854  2022-06-14  INTERFERENCE WITH PUBLIC OFFICER            3
#
#         arrest_count  false_count
# 0                  9           50
# 1                 26            6
# 2                 16           62
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141855 entries, 0 to 141854
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          141855 non-null  object
#  1   primary_type  141855 non-null  object
#  2   crime_count   141855 non-null  int64
#  3   arrest_count  141855 non-null  int64
#  4   false_count   141855 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 5.4+ MB

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df.head()
# Out:
#          date         primary_type  crime_count  arrest_count  false_count  \
# 0  2001-01-01  MOTOR VEHICLE THEFT           59             9           50
# 1  2001-01-01    WEAPONS VIOLATION           32            26            6
# 2  2001-01-01   DECEPTIVE PRACTICE           78            16           62
# 3  2001-01-01    CRIMINAL TRESPASS           29            17           12
# 4  2001-01-01             GAMBLING            2             2            0
#
#    year
# 0  2001
# 1  2001
# 2  2001
# 3  2001
# 4  2001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141855 entries, 0 to 141854
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          141855 non-null  object
#  1   primary_type  141855 non-null  object
#  2   crime_count   141855 non-null  int64
#  3   arrest_count  141855 non-null  int64
#  4   false_count   141855 non-null  int64
#  5   year          141855 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 6.5+ MB

# %%
df['year'] = df['year'].astype(int)
df
# Out:
#               date                      primary_type  crime_count  \
# 0       2001-01-01               MOTOR VEHICLE THEFT           59
# 1       2001-01-01                 WEAPONS VIOLATION           32
# 2       2001-01-01                DECEPTIVE PRACTICE           78
# 3       2001-01-01                 CRIMINAL TRESPASS           29
# 4       2001-01-01                          GAMBLING            2
# ...            ...                               ...          ...
# 141850  2022-06-14                         NARCOTICS           15
# 141851  2022-06-14                 CRIMINAL TRESPASS           11
# 141852  2022-06-14                     OTHER OFFENSE           33
# 141853  2022-06-14                 WEAPONS VIOLATION           29
# 141854  2022-06-14  INTERFERENCE WITH PUBLIC OFFICER            3
#
#         arrest_count  false_count  year
# 0                  9           50  2001
# 1                 26            6  2001
# 2                 16           62  2001
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141855 entries, 0 to 141854
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          141855 non-null  object
#  1   primary_type  141855 non-null  object
#  2   crime_count   141855 non-null  int64
#  3   arrest_count  141855 non-null  int64
#  4   false_count   141855 non-null  int64
#  5   year          141855 non-null  int32
# dtypes: int32(1), int64(3), object(2)
# memory usage: 6.0+ MB

# %%
df_sorted=df.loc[df['year'].isin([2020,2021,2022])].reset_index()
df_sorted
# Out:
#         index        date                      primary_type  crime_count  \
# 0      129706  2020-01-01                           ASSAULT           57
# 1      129707  2020-01-01                             THEFT          117
# 2      129708  2020-01-01                     OTHER OFFENSE           71
# 3      129709  2020-01-01                           ROBBERY           21
# 4      129710  2020-01-01           CRIMINAL SEXUAL ASSAULT           19
# ...       ...         ...                               ...          ...
# 12144  141850  2022-06-14                         NARCOTICS           15
# 12145  141851  2022-06-14                 CRIMINAL TRESPASS           11
# 12146  141852  2022-06-14                     OTHER OFFENSE           33
# 12147  141853  2022-06-14                 WEAPONS VIOLATION           29
# 12148  141854  2022-06-14  INTERFERENCE WITH PUBLIC OFFICER            3
#
#        arrest_count  false_count  year
# 0                12           45  2020
# ...

# %%
df_sample=df_sorted.sample(n=1000)
df_sample
# Out:
#         index        date                primary_type  crime_count  \
# 5766   135472  2021-02-08                    BURGLARY            9
# 9931   139637  2021-12-21                    BURGLARY           17
# 4694   134400  2020-11-18         MOTOR VEHICLE THEFT           35
# 11289  140995  2022-04-08        LIQUOR LAW VIOLATION            1
# 6241   135947  2021-03-15                     ROBBERY           17
# ...       ...         ...                         ...          ...
# 10805  140511  2022-03-01                     ROBBERY           21
# 5815   135521  2021-02-12  OFFENSE INVOLVING CHILDREN            4
# 2387   132093  2020-06-15                     BATTERY          135
# 919    130625  2020-02-28                       THEFT          141
# 8945   138651  2021-10-05                    BURGLARY           24
#
#        arrest_count  false_count  year
# 5766              2            7  2021
# 9931              1           16  2021
# 4694              1           34  2020
# ...

# %%
df_sample.to_csv("crime_data_revised2.csv")

# %%
df_sample.to_json("crime_data.json", orient="records", index=True)

# %%
df_crime_count = df_sample.groupby(['year','primary_type'])['crime_count'].count().reset_index()
df_crime_count
# Out:
#     year                       primary_type  crime_count
# 0   2020                              ARSON            1
# 1   2020                            ASSAULT           28
# 2   2020                            BATTERY           30
# 3   2020                           BURGLARY           23
# 4   2020  CONCEALED CARRY LICENSE VIOLATION           12
# ..   ...                                ...          ...
# 72  2022             PUBLIC PEACE VIOLATION            9
# 73  2022                            ROBBERY            2
# 74  2022                        SEX OFFENSE            3
# 75  2022                              THEFT           15
# 76  2022                  WEAPONS VIOLATION           14
#
# [77 rows x 3 columns]

# %%
df_arrest_count = df_sample.groupby(['year','primary_type'])['arrest_count'].count().reset_index()
df_arrest_count
# Out:
#     year                       primary_type  arrest_count
# 0   2020                              ARSON             1
# 1   2020                            ASSAULT            28
# 2   2020                            BATTERY            30
# 3   2020                           BURGLARY            23
# 4   2020  CONCEALED CARRY LICENSE VIOLATION            12
# ..   ...                                ...           ...
# 72  2022             PUBLIC PEACE VIOLATION             9
# 73  2022                            ROBBERY             2
# 74  2022                        SEX OFFENSE             3
# 75  2022                              THEFT            15
# 76  2022                  WEAPONS VIOLATION            14
#
# [77 rows x 3 columns]

# %%
##df_arrest_count.plot.bar()

# %%
df_sample.groupby(['primary_type','year'])['arrest_count'].count().unstack().plot.bar(subplots = True, figsize = (12,8))
# Out:
# array([<AxesSubplot:title={'center':'2020'}, xlabel='primary_type'>,
#        <AxesSubplot:title={'center':'2021'}, xlabel='primary_type'>,
#        <AxesSubplot:title={'center':'2022'}, xlabel='primary_type'>],
#       dtype=object)

# %%
## step 1, get the data
x1 = df_arrest_count.primary_type
x2 = df_arrest_count.year
y = df_arrest_count.arrest_count


# step 2, init the plot
fig = plt.figure(figsize=(10,8))
plt.bar(x1,x2, y, color="coral")

# step 3, customization
plt.title("Number of Arrests from 2020 to 2022")
plt.ylabel("Number of Arrests")
plt.grid(axis="y", alpha=0.25)

# Sets the x limits of the current chart
plt.xticks(rotation=90, fontsize = 10)

# Sets the y limits of the current chart
plt.ylim(0, max(y)+20)

# step 4, saving/showing
plt.show()
